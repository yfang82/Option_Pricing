# %%
import numpy as np
import matplotlib.pyplot as plt
from IterativePricing import IterativePricing

# %%
ip = IterativePricing(r = 0.05, sigma = 0.2, K = 45, T = 0.5, num_nodes= 16)

# %%
ip.taos
# Out:
# array([0.        , 0.03333333, 0.06666667, 0.1       , 0.13333333,
#        0.16666667, 0.2       , 0.23333333, 0.26666667, 0.3       ,
#        0.33333333, 0.36666667, 0.4       , 0.43333333, 0.46666667,
#        0.5       ])

# %%
for i in range(10):
    if i == 0:
        B = ip.first_iteration()
    else:
        B = ip.single_iteration(B)
B
# Out:
# array([45.        , 41.95138139, 41.13090365, 40.56060296, 40.11994507,
#        39.7582194 , 39.45040121, 39.18198126, 38.94377026, 38.72953026,
#        38.53482688, 38.35637561, 38.19168341, 38.03878382, 37.89617985,
#        37.76207068])

# %%
ip.calc_put_value(45,B)
# Out:
# 2.095605219606699
